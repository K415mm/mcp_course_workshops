# %% [markdown]
# <a href="https://colab.research.google.com/github/K415mm/mcp_course_workshops/blob/main/module_01_intro/01_first_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🤖 Workshop 1: Your First Agent
#
# Welcome to your very first practical workshop! In this notebook, we are going to build a simple AI agent that can solve a basic problem using an API.
#
# ### Prerequisites
# You will need an API key. You can get a free one from [Groq](https://console.groq.com/keys) to run open-source models at blazing speeds.

# %%
# !pip install groq langchain-groq -q
print("✅ Libraries installed successfully!")

# %%
import os
from google.colab import userdata

# This securely grabs the key you save in Colab's 'Secrets' tab (the key icon on the left)
try:
    os.environ['GROQ_API_KEY'] = userdata.get('GROQ_API_KEY')
    print("✅ API Key successfully loaded!")
except userdata.SecretNotFoundError:
    print("❌ ERROR: Please add your GROQ_API_KEY to the Colab Secrets tab!")
